# %% [markdown]
# <a href="https://colab.research.google.com/github/bankehsaz/SMA/blob/main/SMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import necessary libraries
import numpy as np
import pandas as pd
import plotly.express as px
import yfinance as yf

# %%
# getting data from yahoo finance
df = yf.download(tickers='GLD', start='2020-01-01', end='2024-01-01')
df.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-05-15  187.300003  187.880005  187.029999  187.210007  187.210007
# 2023-05-16  186.580002  186.820007  184.460007  184.869995  184.869995
# 2023-05-17  184.309998  184.449997  183.479996  184.229996  184.229996
# 2023-05-18  182.100006  182.279999  181.339996  181.839996  181.839996
# 2023-05-19  182.250000  184.339996  181.809998  183.639999  183.639999
#
#              Volume
# Date
# 2023-05-15  5518100
# 2023-05-16  9519500
# 2023-05-17  7474300
# 2023-05-18  8812600
# 2023-05-19  8432300

# %%
# plotting the close price of SPDR Gold Shares (GLD)
px.line(df, x=df.index, y='Close')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# calculation of the log return
# pct_change gives us Net return: Rt=(Pt/Pt-1) - 1
# to calculate Log Return we have to use Gross Return: Rt + 1
df['Log-Ret'] = np.log(df['Close'].pct_change(1) + 1)
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-05-15  187.300003  187.880005  187.029999  187.210007  187.210007
# 2023-05-16  186.580002  186.820007  184.460007  184.869995  184.869995
# 2023-05-17  184.309998  184.449997  183.479996  184.229996  184.229996
# 2023-05-18  182.100006  182.279999  181.339996  181.839996  181.839996
# 2023-05-19  182.250000  184.339996  181.809998  183.639999  183.639999
#
#              Volume   Log-Ret
# Date
# 2023-05-15  5518100  0.002139
# 2023-05-16  9519500 -0.012578
# 2023-05-17  7474300 -0.003468
# 2023-05-18  8812600 -0.013058
# 2023-05-19  8432300  0.009850

# %%
# plotting the Log Return of SPDR Gold Shares (GLD)
px.line(df, x=df.index, y='Log-Ret', title='SPDR Gold Shares (GLD)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Simple Moving Average calculation
df['SMA-20'] = df['Close'].rolling(20).mean()
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-05-15  187.300003  187.880005  187.029999  187.210007  187.210007
# 2023-05-16  186.580002  186.820007  184.460007  184.869995  184.869995
# 2023-05-17  184.309998  184.449997  183.479996  184.229996  184.229996
# 2023-05-18  182.100006  182.279999  181.339996  181.839996  181.839996
# 2023-05-19  182.250000  184.339996  181.809998  183.639999  183.639999
#
#              Volume   Log-Ret      SMA-20
# Date
# 2023-05-15  5518100  0.002139  186.595502
# 2023-05-16  9519500 -0.012578  186.526501
# 2023-05-17  7474300 -0.003468  186.470001
# 2023-05-18  8812600 -0.013058  186.257501
# 2023-05-19  8432300  0.009850  186.227001

# %%
# plotting the close price of SPDR Gold Shares (GLD) with SMA-20
px.line(df, x=df.index, y=['Close', 'SMA-20'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Simple Moving Average calculation
df['SMA-60'] = df['Close'].rolling(60).mean()
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-05-15  187.300003  187.880005  187.029999  187.210007  187.210007
# 2023-05-16  186.580002  186.820007  184.460007  184.869995  184.869995
# 2023-05-17  184.309998  184.449997  183.479996  184.229996  184.229996
# 2023-05-18  182.100006  182.279999  181.339996  181.839996  181.839996
# 2023-05-19  182.250000  184.339996  181.809998  183.639999  183.639999
#
#              Volume   Log-Ret      SMA-20      SMA-60
# Date
# 2023-05-15  5518100  0.002139  186.595502  181.359167
# 2023-05-16  9519500 -0.012578  186.526501  181.586000
# 2023-05-17  7474300 -0.003468  186.470001  181.812834
# 2023-05-18  8812600 -0.013058  186.257501  182.015834
# 2023-05-19  8432300  0.009850  186.227001  182.250333

# %%
# plotting the close price of SPDR Gold Shares (GLD) with SMA-20 and SMA-60
px.line(df, x=df.index, y=['Close', 'SMA-20', 'SMA-60'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
